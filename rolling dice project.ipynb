# %%
import random 
from matplotlib import image as img 
from matplotlib import pyplot as plt 


number = random.randint(1,6)
print(number)

if number == 1 :
    plt.title("dice-1-md.png") 
    image = img.imread(r"D:\Python\assignments\rolling dice project\dice-1-md.png")       
    plt.imshow(image)
    plt.show()

elif number == 2 :
    plt.title("dice-2-md.png")
    image = img.imread(r"D:\Python\assignments\rolling dice project\dice-2-md.png")
    plt.imshow(image)
    plt.show()
    
elif number == 3 :
    plt.title("dice 3.jpg")
    image = img.imread(r"D:\Python\assignments\rolling dice project\dice 3.jpg")
    plt.imshow(image)
    plt.show()

elif number == 4 :
    plt.title("dice 4.jpg")
    image = img.imread(r"D:\Python\assignments\rolling dice project\dice 4.jpg")
    plt.imshow(image)
    plt.show()

elif number == 5 :
    plt.title("dice 5.jpg")
    image = img.imread(r"D:\Python\assignments\rolling dice project\dice 5.jpg")
    plt.imshow(image)
    plt.show()

else :
    plt.title("dice 6.jpg")
    image = img.imread(r"D:\Python\assignments\rolling dice project\dice 6.jpg")
    plt.imshow(image)
    plt.show()
# Out:
# 4
